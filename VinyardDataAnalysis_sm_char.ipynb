# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chardonnay_df = pd.read_csv("/Users/scott/Bootcamp Lessons and Exercises/Project 1 work/chardonnay.csv")

# %%
cols = list(chardonnay_df.columns)
cols.remove('Unnamed: 0')
char_df = chardonnay_df.loc[:,cols]

# %%
char_df.head()
# Out:
#                                                 wine     variety country  \
# 0           Mirassou 2012 Chardonnay (Central Coast)  Chardonnay      US
# 1  RustRidge 2010 Estate Bottled Chardonnay (Napa...  Chardonnay      US
# 2            Souverain 2010 Chardonnay (North Coast)  Chardonnay      US
# 3                      Simonnet-Febvre 2015  Chablis  Chardonnay  France
# 4  Vignerons des Terres Secrètes 2015  Mâcon-Mill...  Chardonnay  France
#
#    points  price          taster
# 0      87   12.0   Matt Kettmann
# 1      85   30.0             NaN
# 2      85   14.0  Virginie Boone
# 3      86   24.0      Roger Voss
# 4      86   15.0      Roger Voss

# %%
plt.figure(figsize=(18,8))
sns.lmplot(x='price',y='points', data = char_df, fit_reg = False)
plt.title('Pinot Noir Ratings by Price')
plt.grid()
plt.show()

# %%
#SNS Violin plot, width shows how many wines are at that point value
plt.figure(figsize=(18,8))
plot = sns.violinplot(x='country', y = 'points', data = char_df, size = 100)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.lmplot(x='country',y='points', data = char_df, fit_reg = False)
plt.xticks(rotation="vertical")
plt.title('Pinot Noir Ratings by Price')
plt.grid()
plt.show()
