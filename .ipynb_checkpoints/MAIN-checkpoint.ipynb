# %%
# dependencies
import tweepy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# sentiment analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# twitter keys
from config import (consumer_key, consumer_secret, access_token, access_token_secret)

# tweepy api authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-99bd16701e8c> in <module>()
#      10
#      11 # twitter keys
# ---> 12 from config import (consumer_key, consumer_secret, access_token, access_token_secret)
#      13
#      14 # tweepy api authentication
#
# ModuleNotFoundError: No module named 'config'

# %%
# read csv and separate into different dataframes
df = pd.read_csv('../../gw/Project_1/winemag-data-130k-v2.csv')
df = df[['title','variety', 'country', 'points', 'price', 'taster_name', 'taster_twitter_handle']]
df = df.rename(columns={'title':'wine', 'taster_name':'taster', 'taster_twitter_handle':'twitter handle'})
df.dropna(axis=0, how='any')

whites = ['Riesling', 'White Blend', 'Chardonnay', 'Sauvignon Blanc']
reds = ['Merlot', 'Sangiovese', 'Red Blend', 'Pinot Noir']
both = ['Riesling', 'White Blend', 'Chardonnay', 'Sauvignon Blanc', 'Merlot', 'Sangiovese', 'Red Blend', 'Pinot Noir']

df = df.loc[df['variety'].isin(both)]
whites_df = df.loc[df['variety'].isin(whites)]
reds_df = df.loc[df['variety'].isin(reds)]

# %%
# white wine ratings by price
plt.figure(figsize=(10,6))
plt.scatter(whites_df['price'], whites_df['points'])
plt.title('White Wine Ratings by Price')
plt.xlabel('Price')
plt.ylabel('Points')
plt.grid()
plt.show()
plt.savefig('ratings_by_price_WHITES.png')

# %%
# white whine ratings by country
plt.figure(figsize=(18,8))
plot = sns.violinplot(x= 'country', y = 'points', data = whites_df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
plt.title('White Wine Ratings by Country')
plt.grid()
plt.xlabel('Country')
plt.ylabel('Points')
plt.show()
plt.savefig('ratings_by_country_WHITES.png')

# %%
# white wine prices by country
plt.figure(figsize=(18,8))
plt.scatter(whites_df['country'], whites_df['price'])
plt.xticks(rotation='vertical')
plt.title('White Wine Prices by Country')
plt.xlabel('Country')
plt.ylabel('Price')
plt.grid()
plt.show()
plt.savefig('prices_by_country_WHITES.png')

# %%
# bougiest white wines (by points and price)
whites_bougiest = whites_df.groupby(['country'])['points', 'price'].max()
whites_bougiest.sort_values('points', ascending = False)
# Out:
#                 points   price
# country
# France             100   886.0
# US                  99  2013.0
# Germany             98   775.0
# Hungary             97    80.0
# Austria             97   160.0
# Italy               97   375.0
# England             95    80.0
# New Zealand         94    80.0
# Canada              94    90.0
# South Africa        94    80.0
# Australia           94   200.0
# Spain               93    95.0
# Slovenia            92    90.0
# Israel              92    53.0
# Argentina           92   120.0
# Portugal            92    40.0
# Romania             92   320.0
# Greece              91    45.0
# Chile               91    95.0
# Bulgaria            91    23.0
# India               90    12.0
# Georgia             90    17.0
# Switzerland         90    21.0
# Croatia             90    41.0
# Moldova             90    42.0
# Turkey              89    18.0
# Serbia              89    22.0
# Lebanon             89    41.0
# Morocco             89    18.0
# ...
