# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('riesling.csv')
df = df.drop(columns=['Unnamed: 0'])
df = df.dropna(axis=0, how='any')
df.head()
# Out:
#                                                  wine   variety  country  \
# 12  Claiborne & Churchill 2014 Claiborne Vineyard ...  Riesling       US
# 20      Red Newt Cellars 2007 Riesling (Finger Lakes)  Riesling       US
# 21  Pomum 2014 Upland Vineyard Riesling (Snipes Mo...  Riesling       US
# 26    Landhaus Mayer 2016 Riesling (Niederösterreich)  Riesling  Austria
# 27          Malat 2016 Furth-Palt Riesling (Kremstal)  Riesling  Austria
#
#     points  price            taster twitter handle
# 12      91   28.0     Matt Kettmann  @mattkettmann
# 20      85   14.0   Susan Kostrzewa  @suskostrzewa
# 21      89   16.0  Sean P. Sullivan  @wawinereport
# 26      89   16.0  Anne Krebiehl MW    @AnneInVino
# 27      89   24.0  Anne Krebiehl MW    @AnneInVino

# %%
plt.figure(figsize=(18,8))
plt.scatter(df['price'], df['points'])
plt.title('Riesling Ratings by Price')
plt.xlabel('Price')
plt.ylabel('Points')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(18,8))
plot = sns.violinplot(x='country', y = 'points', data = df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
plt.title('Riesling Ratings by Country')
plt.grid()
plt.xlabel('Country')
plt.ylabel('Points')
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.scatter(df['country'], df['price'])
plt.xticks(rotation='vertical')
plt.title('Riesling Prices by Country')
plt.xlabel('Country')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
bougiest = df.groupby(['country'])['points', 'price'].max()
bougiest.sort_values('points', ascending = False)
# Out:
#                 points  price
# country
# France              97  120.0
# Germany             97  612.0
# Austria             96  145.0
# US                  96  200.0
# Canada              94   90.0
# Australia           94   65.0
# New Zealand         93   55.0
# Italy               92   40.0
# South Africa        90   24.0
# Israel              90   15.0
# Moldova             90   23.0
# Portugal            90   23.0
# Serbia              89   22.0
# Chile               89   39.0
# Slovenia            89   36.0
# Luxembourg          88   23.0
# Ukraine             88    9.0
# Czech Republic      88   15.0
# Bulgaria            87   22.0
# Argentina           86   15.0
# Romania             85  320.0
# Spain               82   20.0
