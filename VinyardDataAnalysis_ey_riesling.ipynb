# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('riesling.csv')
df = df.drop(columns=['Unnamed: 0'])
df = df.dropna(axis=0, how='any')
df.head()
# Out:
#                                                 wine   variety  country  \
# 0  St. Julian 2013 Reserve Late Harvest Riesling ...  Riesling       US
# 1        Richard Böcking 2013 Devon Riesling (Mosel)  Riesling  Germany
# 3          Schmitt Söhne 2015 Riesling (Rheinhessen)  Riesling  Germany
# 4  P.J. Valckenberg 2015 Undone Dry Riesling (Rhe...  Riesling  Germany
# 5  Heron Hill 2015 Ingle Vineyard Riesling (Finge...  Riesling       US
#
#    points  price              taster
# 0      87   13.0  Alexander Peartree
# 1      87   24.0  Anna Lee C. Iijima
# 3      86    9.0  Anna Lee C. Iijima
# 4      86   10.0  Anna Lee C. Iijima
# 5      88   20.0  Anna Lee C. Iijima

# %%
plt.figure(figsize=(18,8))
plt.scatter(df['price'], df['points'])
plt.title('Riesling Ratings by Price')
plt.xlabel('Price')
plt.ylabel('Points')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(18,8))
plot = sns.violinplot(x='country', y = 'points', data = df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
plt.title('Riesling Ratings by Country')
plt.grid()
plt.xlabel('Country')
plt.ylabel('Points')
plt.show()

# %%
plt.figure(figsize=(18,8))
plt.scatter(df['country'], df['price'])
plt.xticks(rotation='vertical')
plt.title('Riesling Prices by Country')
plt.xlabel('Country')
plt.ylabel('Price')
plt.grid()
plt.show()
