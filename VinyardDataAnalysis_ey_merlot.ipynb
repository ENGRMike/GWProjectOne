# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('merlot.csv')
df = df.drop(columns=['Unnamed: 0'])
df = df.dropna(axis=0, how='any')
df.head()
# Out:
#                                                 wine variety country  points  \
# 0  Bianchi 2011 Signature Selection Merlot (Paso ...  Merlot      US      87
# 1                Sundance 2011 Merlot (Maule Valley)  Merlot   Chile      86
# 2  Passaggio 2014 Blau Vineyards Merlot (Knights ...  Merlot      US      86
# 3  Duckhorn 2012 Rector Creek Vineyard Merlot (Na...  Merlot      US      91
# 4  Viña Bisquertt 2007 Casa La Joya Reserve Merlo...  Merlot   Chile      88
#
#    price             taster twitter handle
# 0   22.0      Matt Kettmann  @mattkettmann
# 1    9.0  Michael Schachner    @wineschach
# 2   55.0     Virginie Boone        @vboone
# 3   95.0     Virginie Boone        @vboone
# 4   11.0  Michael Schachner    @wineschach

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['price'], df['points'])
plt.title('Merlot Ratings by Price')
plt.xlabel('Price')
plt.ylabel('Points')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(18,8))
plot = sns.violinplot(x='country', y = 'points', data = df)
plot.set_xticklabels(plot.get_xticklabels(), rotation=90)
plt.title('Merlot Ratings by Country')
plt.grid()
plt.xlabel('Country')
plt.ylabel('Points')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['country'], df['price'])
plt.xticks(rotation='vertical')
plt.title('Merlot Prices by Country')
plt.xlabel('Country')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
bougiest = df.groupby(['country'])['points', 'price'].max()
bougiest.sort_values('points', ascending = False)
# Out:
#               points  price
# country
# Italy             97  625.0
# US                96  200.0
# Argentina         94  120.0
# Austria           94   44.0
# Portugal          93   30.0
# New Zealand       93   50.0
# Canada            93   50.0
# France            93  128.0
# Israel            92   60.0
# Greece            92   59.0
# Chile             92   35.0
# Spain             91   40.0
# Australia         90   86.0
# Bulgaria          90   19.0
# South Africa      90   45.0
# Slovenia          89   37.0
# Brazil            88   50.0
# Romania           88  100.0
# Moldova           87    9.0
# Turkey            86  120.0
# Ukraine           84    9.0
# Uruguay           84   16.0
# Switzerland       83   38.0
# Mexico            82   30.0
